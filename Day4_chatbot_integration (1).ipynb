# %%
import google.generativeai as genai

API_KEY = "Your_API_KEY"


genai.configure(api_key=API_KEY)

model = genai.GenerativeModel("gemini-2.5-flash")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = model.generate_content(user_input)

    print("\nBot:", response.text)
    print()
# Out:
# You: what is python
#
# Bot: Python is a **high-level, interpreted, general-purpose programming language**. It was created by Guido van Rossum and first released in 1991.
#
# Here's a breakdown of what that means and why it's so popular:
#
# 1.  **High-Level:**
#     *   This means Python code is closer to human language than machine language. You don't have to worry about low-level details like memory management, which makes it much easier to read, write, and maintain.
#
# 2.  **Interpreted:**
#     *   Unlike compiled languages (like C++ or Java), Python code is executed line by line at runtime by an interpreter. You don't need a separate compilation step, which speeds up the development process.
#
# 3.  **General-Purpose:**
#     *   This is a key strength of Python. It's not designed for a specific task but can be used for a vast array of applications across different domains. Think of it like a Swiss Army knife for programming.
#
# ---
#
# ### Key Characteristics and Why Python is Popular:
#
# *   **Readability and Simplicity:** Python's syntax is designed to be very clean and readable, often compared to pseudocode. It emphasizes natural language and uses indentation to define code blocks, making it easier to learn, especially for beginners.
# *   **Versatility (General-Purpose):** As mentioned, Python can do almost anything.
# *   **Large Standard Library & Ecosystem:** Python comes with a vast "batteries-included" standard library, meaning it has modules for many common tasks. Beyond that, there's an enormous ecosystem of third-party libraries and frameworks for specific purposes.
# *   **Cross-Platform:** Python code can run on various operating systems (Windows, macOS, Linux, etc.) with little to no modification.
# *   **Object-Oriented:** Python supports object-oriented programming (OOP), which is a powerful way to structure programs using "objects" that contain both data and functions. It also supports other programming paradigms like procedural and functional.
# *   **Dynamic Typing:** You don't have to declare the type of a variable (e.g., integer, string) when you create it; Python figures it out at runtime. This adds flexibility but also means type-related errors might only appear during execution.
# *   **Large and Active Community:** Python has a massive global community of developers who contribute to its development, create libraries, and provide support.
#
# ---
#
# ### What Python is Used For (Applications):
#
# Python's versatility means it's used in almost every industry:
#
# *   **Web Development:** Powering websites and web applications (e.g., Django, Flask frameworks).
# *   **Data Science & Machine Learning (AI):** A dominant force due to libraries like NumPy, Pandas, Scikit-learn, TensorFlow, and PyTorch. Used for data analysis, visualization, AI, deep learning, and predictive modeling.
# *   **Automation & Scripting:** Automating repetitive tasks, system administration, and DevOps.
# *   **Desktop GUIs:** Creating graphical user interfaces for desktop applications (e.g., Tkinter, PyQt).
# *   **Scientific and Numeric Computing:** Used by researchers and engineers for complex calculations and simulations.
# *   **Game Development:** While not typically used for AAA titles, it's popular for prototyping and indie games (e.g., Pygame).
# *   **Education:** Its simplicity makes it an excellent language for teaching programming concepts.
# *   **Network Programming, Software Testing, Web Scraping, and much more.**
#
# ---
#
# In essence, Python is a powerful, flexible, and easy-to-learn programming language that has become one of the most popular choices for a wide range of applications, from building websites to developing cutting-edge AI.
#
# You: exit
