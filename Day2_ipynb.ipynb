# %%
## problem1: postive negative or zero
num=int(input("enter a number:"))
if num>0:
  print("positive number")
elif num<0:
  print("negative number")
else:
  print("zero")
# Out:
# enter a number:-5
# negative number

# %%
## Problem2:sum of digits
n= int(input("Enter a number: "))
sum_of_digits = 0
while n > 0:
    digit = n % 10
    sum_of_digits = sum_of_digits + digit
    n //= 10
print("Sum of digits:", sum_of_digits)
# Out:
# Enter a number: 156
# Sum of digits: 12

# %%
## problem4:calculator
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

choice = input("Enter operation (+, -, *, /): ")

if choice == "+":
    print("Result:", add(num1, num2))
elif choice == "-":
    print("Result:", subtract(num1, num2))
elif choice == "*":
    print("Result:", multiply(num1, num2))
elif choice == "/":
    print("Result:", divide(num1, num2))
else:
    print("Invalid operation")
# Out:
# Enter first number: 36
# Enter second number: 3
# Enter operation (+, -, *, /): /
# Result: 12.0

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

choice = input("Enter operation (+, -, *, /): ")

if choice == "+":
    print("Result:", add(num1, num2))
elif choice == "-":
    print("Result:", subtract(num1, num2))
elif choice == "*":
    print("Result:", multiply(num1, num2))
elif choice == "/":
    print("Result:", divide(num1, num2))
else:
    print("Invalid operation")
# Out:
# Enter first number: 14
# Enter second number: 34
# Enter operation (+, -, *, /): -
# Result: -20.0

# %%
## problem3:reverse a number
num = int(input("Enter a number: "))
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

print("Reversed number:", reverse)
# Out:
# Enter a number: 321
# Reversed number: 123

# %%
marks = []

for i in range(5):
    mark = int(input("Enter mark: "))
    marks.append(mark)

highest = max(marks)
lowest = min(marks)
average = __builtins__.sum(marks) / len(marks)

print("Marks:", marks)
print("Highest:", highest)
print("Lowest:", lowest)
print("Average:", average)
# Out:
# Enter mark: 13
# Enter mark: 15
# Enter mark: 18
# Enter mark: 56
# Enter mark: 78
# Marks: [13, 15, 18, 56, 78]
# Highest: 78
# Lowest: 13
# Average: 36.0
